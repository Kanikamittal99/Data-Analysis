# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# "fivethirtyeight" styling, which tries to replicate the styles from FiveThirtyEight.com which is an American website that focuses on opinion poll analysis, politics, economics, and sports blogging.

# %%
#setting fivethirtyeight style
plt.style.use('fivethirtyeight')

# %%
data_2015 = pd.read_csv('2015.csv')
data_2016 = pd.read_csv('2016.csv')
data_2017 = pd.read_csv('2017.csv')

# %%
data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# ##### Correlations b/w data

# %%
plt.figure(figsize = (20,15)) #figsize accepts inches
sns.heatmap(data_2017.corr(), cmap= 'copper', annot= True) #corr() -> TF correlation among the columns

plt.show()

# %% [markdown]
# ### correlations for Western europe

# %%
df = pd.DataFrame(data_2015)
df = df.loc[df['Region'] == 'Western Europe']
df
# Out:
#             Country          Region  Happiness Rank  Happiness Score  \
# 0       Switzerland  Western Europe               1            7.587
# 1           Iceland  Western Europe               2            7.561
# 2           Denmark  Western Europe               3            7.527
# 3            Norway  Western Europe               4            7.522
# 5           Finland  Western Europe               6            7.406
# 6       Netherlands  Western Europe               7            7.378
# 7            Sweden  Western Europe               8            7.364
# 12          Austria  Western Europe              13            7.200
# 16       Luxembourg  Western Europe              17            6.946
# 17          Ireland  Western Europe              18            6.940
# 18          Belgium  Western Europe              19            6.937
# 20   United Kingdom  Western Europe              21            6.867
# 25          Germany  Western Europe              26            6.750
# ...

# %%
plt.figure(figsize = (10,6))
sns.heatmap(df.corr(), cmap = 'pink', annot = True)
plt.show()

# %% [markdown]
# Happiness in European region is highly correlated with Economy, Family, Freedom, Trust, Generosity.

# %% [markdown]
# ### Correlation for Eastern Asia

# %%
df_EA = pd.DataFrame(data_2015)
df_EA = df.loc[df['Region'] == 'Eastern Asia']
df_EA
# Out:
#         Country        Region  Happiness Rank  Happiness Score  \
# 37       Taiwan  Eastern Asia              38            6.298
# 45        Japan  Eastern Asia              46            5.987
# 46  South Korea  Eastern Asia              47            5.984
# 71    Hong Kong  Eastern Asia              72            5.474
# 83        China  Eastern Asia              84            5.140
# 99     Mongolia  Eastern Asia             100            4.874
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 37         0.03868                   1.29098  1.07617
# 45         0.03581                   1.27074  1.25712
# 46         0.04098                   1.24461  0.95774
# 71         0.05051                   1.38604  1.05818
# 83         0.02424                   0.89012  0.94675
# 99         0.03313                   0.82819  1.30060
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_EA.corr(), cmap = 'Oranges', annot = True)
plt.show()
